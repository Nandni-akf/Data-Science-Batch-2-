# %%
import pandas as pd

df_country_wise = pd.read_csv('/content/country_wise_latest.csv')
display(df_country_wise)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
import pandas as pd

df_country_wise = pd.read_csv('/content/country_wise_latest.csv')
recovery_rate = (df['Recovered'].sum() /
                 df['Confirmed'].sum()) * 100

print("Recovery Rate:", recovery_rate)
# Out:
# Recovery Rate: 46.88041672939686

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("country_wise_latest.csv")

# Top 10 countries with highest daily new cases
top_daily = df.sort_values(by='New cases', ascending=False)

print(top_daily[['Country/Region', 'New cases']].head(10))
# Out:
#     Country/Region  New cases
# 173             US      56336
# 79           India      44457
# 23          Brazil      23284
# 37        Colombia      16306
# 132           Peru      13756
# 154   South Africa       7096
# 138         Russia       5607
# 111         Mexico       4973
# 6        Argentina       4890
# 13      Bangladesh       2772

# %%
import pandas as pd

df_country_wise = pd.read_csv('/content/country_wise_latest.csv')
death_rate = (df['Deaths'].sum() /
              df['Confirmed'].sum()) * 100
print("Death Rate:", death_rate)
# Out:
# Death Rate: 5.23650680018023

# %%
import pandas as pd

df = pd.read_csv("country_wise_latest.csv")

# Calculate rates
df['Recovery Rate'] = (df['Recovered'] / df['Confirmed']) * 100
df['Death Rate'] = (df['Deaths'] / df['Confirmed']) * 100

# Top 10 countries by confirmed cases
top10 = df.sort_values(by='Confirmed', ascending=False).head(10)

print(top10[['Country/Region',
             'Confirmed',
             'Deaths',
             'Recovered',
             'Recovery Rate',
             'Death Rate']])
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Recovery Rate  Death Rate
# 173              US    4290259  148011    1325804      30.902656    3.449932
# 23           Brazil    2442375   87618    1846641      75.608414    3.587410
# 79            India    1480073   33408     951166      64.264803    2.257186
# 138          Russia     816680   13334     602249      73.743572    1.632708
# 154    South Africa     452529    7067     274925      60.753013    1.561668
# 111          Mexico     395489   44022     303810      76.818824   11.131030
# 132            Peru     389717   18418     272547      69.934594    4.725993
# 35            Chile     347923    9187     319954      91.961152    2.640527
# 177  United Kingdom     301708   45844       1437       0.476288   15.194824
# 81             Iran     293606   15912     255144      86.900131    5.419508
