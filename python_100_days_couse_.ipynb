# %% [markdown]
# <a href="https://colab.research.google.com/github/Nandni-akf/Data-Science-Batch-2-/blob/main/python_100_days_couse_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World \n Hello World")
# Out:
# Hello World
#  Hello World

# %%
print("hello"+"angela")
# Out:
# helloangela

# %%
print(" hello"+ " angela")
# Out:
#  hello angela

# %%
print("hello"+" "+"angela")
# Out:
# hello angela

# %%
print("hello"+ input("what is your name"))
# Out:
# what is your namenandni
# hellonandni

# %%
print("hello "+ input("what is your name ")+"!")
# Out:
# what is your name cheery
# hello cheery!

# %%
by using ctrl plus / we get a # sign

# %%
name=input("what is your name?")
print("name")
# if we write the print instaed of the input than it will be print the statemnet only not asking the name

# %%
# to calcualte the length of a string
name="angela"
print("name")
print(len(name))
# Out:
# name
# 6

# %%
username=input("what is your name")
length=len(username)
print(length)
# Out:
# what is your namenandni
# 6

# %%
Project for today

# %%
print("Welcome to the band name Generator")
city_name=input("in which city you grown up \n")
print(city_name)
pet_name=input("what is your pet name \n")
print(pet_name)
print("your band name could be:"+ city_name +" "+ pet_name)
# Out:
# Welcome to the band name Generator
# in which city you grown up
# mohali
# mohali
# what is your pet name
# rabit
# rabit
# your band name could be:mohali rabit

# %% [markdown]
# **DAY 2**

# %%
print("Hello"[0]) #this indicates the adress of the string value
# Out:
# H

# %%
#string concatenated
print("123"+ "345")
# Out:
# 123345

# %%
print(123+345)
#integer =whole number
# Out:
# 468

# %%
print(12,23+12,21)
# Out:
# 12 35 21

# %% [markdown]
# in python we use underscope _ while giving the space in anyting we cannot use the *comma*

# %%
print(12_23+12_21)
# Out:
# 2444

# %%
len("123")
# only string can tell the length character or an integer by using an simple word ln
# Out:
# 3
